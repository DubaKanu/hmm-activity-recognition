# %% [markdown]
# # Modeling Human Activity States Using Hidden Markov Models
#
# ## Project Overview
# This project collects real motion data from a smartphone and uses a
# Hidden Markov Model (HMM) to automatically recognize four human activities:
# walking, standing, still, and jumping.
#
# ## Motivation
# In real-world systems such as wearable health monitors and smart devices,
# continuous sensor data reveals valuable information about human activity.
# However, the true activity state is hidden behind noisy measurements.
# This project addresses that challenge by training an HMM to infer
# the most likely activity from accelerometer and gyroscope signals.
#
# ## Data Collection
# Data was collected using the Sensor Logger app on a smartphone at 100 Hz.
# Four activities were recorded with 13 clips each (5–10 seconds per clip),
# giving 52 total clips across walking, standing, still, and jumping.
#
# ## Tools and Libraries
# - Python, Google Colab
# - hmmlearn — Hidden Markov Model implementation
# - numpy, pandas — data processing
# - scipy — FFT and signal processing
# - sklearn — normalization and evaluation metrics
# - matplotlib, seaborn — visualization
#
# ## Author
# Josephine Duba Kanu
# African Leadership University
# Formative 2 — July 2025

# %% [markdown]
# # HMM Activity Recognition
# ## Installing Required Libraries
# I install hmmlearn, the Python library used to build and train our Hidden Markov Model.

# %%
# !pip install hmmlearn -q
print("Done!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 kB 3.0 MB/s eta 0:00:00
# Done!

# %% [markdown]
# ## Importing Libraries
# I import all necessary libraries for data loading, feature extraction,
# model training, and visualization.

# %%
import numpy as np
import pandas as pd
import os
from scipy.fft import fft
from scipy.signal import resample
from sklearn.preprocessing import StandardScaler
from hmmlearn import hmm
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score

print("All libraries loaded!")
# Out:
# All libraries loaded!

# %% [markdown]
# ## Mounting Google Drive
# I connected Google Drive to access my recorded sensor data files.

# %%
from google.colab import drive
drive.mount('/content/drive')
print("Google Drive mounted!")
# Out:
# Mounted at /content/drive
# Google Drive mounted!

# %% [markdown]
# ## Loading Data
# I locate the HMM_Project folder in Google Drive and list all recorded activity clips.

# %%
# Check your Drive and find your data folder
import os

base_path = '/content/drive/MyDrive'
print("Folders in your Google Drive:")
for folder in sorted(os.listdir(base_path)):
    print(folder)
# Out:
# Folders in your Google Drive:
#  Empathy Map.pdf
#  International Organization for Migration (IOM).gdoc
#  Josephine Duba Kanu_Mission Portfolio.docx
#  Josephine_Duba_Kanu_Critical Analysis.gdoc
# 1111111111111111111111.png
# AICE_Milestone06_21.04.2024..pdf
# ALA_Cover Letter_Josephine Duba Kanu.gdoc
# ALFRED PASSPORT.gdoc
# Acceptance Email.png
# Advocacy Campaign_Group Summative_Cohort 1 Negpod 3_Josephine Duba Kanu.gslides
# African Union Youth Volunteer Corps (AU-YVC).gdoc
# Alfred Kabba Swaray_ "SMARTRIDE SALONE_Sierra Leone.gdoc
# Alfred Kabba Swaray_LETTER OF RECOMMENDATION.pdf
# As Rise Again is not formally registered as a nonprofit organization, we have not filed any IRS 990, 990EZ, or 990PF forms.gdoc
# Assignment 1.gdoc
# Business Plan_Josephine Duba Kanu.gdoc
# Business Plan_Josephine Duba Kanu.pdf
# Candidate Budget Submission_(Josephine Duba Kanu).gdoc
# Career Services & Alumni Engagement Competitiveness Analysis for Bootcamps.gdoc
# Careers Module Structure: Weeks 2–4.gdoc
# Challenge 4_Hunt For Treasure_ZAMBEZI Catalysts.gdoc
# Challenge 5.gdoc
# Challenge 5.pdf
# Colab Notebooks
# Communicating for Impact_Argumentative Essay_Josephine Duba Kanu.gdoc
# Comprehensive Careers Readiness Module: Program Structure.gdoc
# Confidence Journal.gdoc
# Confirmation of Enrollment and Mastercard Foundation Scholarship Status.gdoc
# Copy of (Make a Copy)Proposal & Software Requirements Specification (SRS) Template (1).gdoc
# Copy of (Make a Copy)Proposal & Software Requirements Specification (SRS) Template.gdoc
# Copy of 2026 Scholars Council Representative Candidate Support packet.docx
# Copy of 2026 Scholars Council Representative Candidate Support packet.docx.pdf
# Copy of Breakout Room Assignment Solution: Exploring Hidden State Sequences in an HMM.gdoc
# Copy of Budget_smaple (1).gdoc
# Copy of Budget_smaple (2).gdoc
# Copy of Budget_smaple.gdoc
# Copy of Class scenario.gdoc
# Copy of Copy of Official JOSEPHINE DUBA KANUResume (CV)_removed_removed.docx
# Copy of Copy of W3 S1- In-class Activity .gdoc
# Copy of Crafting Prompts.gdoc
# Copy of Daibets.ipynb
# Copy of FirstName LastName BSE Student: Reflection questions Year 1 Trimester-2.gsheet
# Copy of Group 4_Formative_CNNs_Report.gdoc
# Copy of Jean d'amour Hakizimana -cohort 1.gdoc
# Copy of Josephine Duba Kanu_C7_Group3.gdoc
# Copy of Josephine Duba Kanu__Assignment1_W4_May 31 2025.gdoc
# Copy of Joy Gitonga_Cohort 2.gdoc
# Copy of MCF EF Report Template.gdoc
# Copy of MCF EF Report Template.pdf
# Copy of Official JOSEPHINE DUBA KANUResume (CV)_removed_removed.docx
# Copy of Peer Editing Checklist (1).gdoc
# Copy of Peer Editing Checklist.gdoc
# Copy of Review Activity.gdoc
# Copy of Sierra Leone-Rwanda Community Membership Registrationa Leone (Responses).gsheet
# Copy of W3 S1- In-class Activity .gdoc
# Copy of [MAKE A COPY] _ E-Lab Work Book_2024.gsheet
# Copy of [Make a Copy] Introduction to google sheets basics (1).xlsx
# Copy of [Make a Copy] Introduction to google sheets basics (2).xlsx
# Copy of [Make a Copy] Introduction to google sheets basics.xlsx
# Copy of [Make a Copy] Practice: Write a thesis statement.gdoc
# Cover Letter – BCG ASPIRE Women’s Workshop.gdoc
# Cover Letter – UNICEF Internship (Social Behavior Change & Behavioral Insights).gdoc
# Cover Letter — Tata Global Internships 2026.gdoc
# Curriculum: Pitch Deck Creation & Presentation Skills.gdoc
# Customer ID.jpg
# Dear Hiring Team,.gdoc
# Duba.pdf
# Empathy map.gdraw
# Empowering Voices Through Digital Storytelling.gdoc
# Enneagram Test Result Reflection.gdoc
# EnrolLetterjosephinedubakanugmail.com-UGJanuary2024IntakeRound1-2023-10-26084023Z-UGEnrolmentOpportunityJosephineDubaKanu.pdf
# Equity bank .jpg
# Essay.gdoc
# Ethics and Values Leadership.gdoc
# Execution Plan: Implementing My Manifesto as GiveBack Community Lead.gdoc
# Execution Plan_ Implementing My Manifesto as GiveBack Community Lead.pdf
# Exemplary Leader Essay (Dr. Abu Bakarr Fofanah.gdoc
# Externship Report: Evaluating the Impact of Zindua School.gdoc
# Financial Sustainability Plan for SafeBirth Sierra Leone_Josephine Duba Kanu.gdoc
# Financial Sustainability Plan for SafeBirth Sierra Leone_Josephine Duba Kanu.pdf
# Fundraising Intern position.gdoc
# GOAL.gdoc
# Governance In Rwanda.gdoc
# Group 1_Formative_CNNs_Report.gdoc
# Group 2 ;Strategies for effective leadership (Newspaper article).gdoc
# Group 4_Formative_CNNs_Report.pdf
# Group Assignment.gdoc
# HMM_Project
# Health Data_Cover Letter.gdoc
# Individual Assignment 2: BookSwap Technical Report.gdoc
# International Youth Month Celebration.gdoc
# Internship Support Letter - New Model Students - signed.pdf
# Introduction: The Conflict in Nigeria.gdoc
# Itinerary for  JOSEPHINE DUBA KANU departing on 16OCT2025 for KGL - NBO.pdf
# JOSEPHINE DUBA KANU CURRICULUM VITAE (CV).docx
# January 2025 Term Registration.png
# Jojo Passport (1).pdf
# Jojo Passport (2).pdf
# Jojo Passport (3).pdf
# Jojo Passport (4).pdf
# Jojo Passport (5).pdf
# Jojo Passport (6).pdf
# Jojo Passport.pdf
# Jojo Student Permit.jpg
# Jojo passport picture Original 11111.jpg
# Jojoooo.jpg
# Josephine Dub Kanu_Financial_Bid.gdoc
# Josephine Duba Kanu -cohort 7.gdoc
# Josephine Duba Kanu .gdoc
# Josephine Duba Kanu Cover Letter For Internship in Healthcare.gdoc
# Josephine Duba Kanu Cover Letter—In Communication Intern at Citadel Real Estate, Kigali.gdoc
# Josephine Duba Kanu Cover Letter—In Communication Intern at Citadel Real Estate, Kigali.pdf
# Josephine Duba Kanu Notarized Result.pdf
# Josephine Duba Kanu Scholar's profile.gslides
# Josephine Duba Kanu Scholar's profile.pdf
# Josephine Duba Kanu – GiveBack Community Lead Manifesto.gdoc
# Josephine Duba Kanu – GiveBack Community Lead Manifesto.pdf
# Josephine Duba Kanu's Statement of Progression_202509RW.pdf
# Josephine Duba Kanu.gdoc
# Josephine Duba Kanu.xlsx
# Josephine Duba Kanu_ QWETU BOOKING FORM.docx
# Josephine Duba Kanu_(Aspen Institute_Cover Letter).gdoc
# Josephine Duba Kanu_AHSU_Cover Letter.gdoc
# Josephine Duba Kanu_Afican Leadership Unversity_Social Impact Tour-2025.gslides
# Josephine Duba Kanu_Alternate Internship Test .gdoc
# Josephine Duba Kanu_Application for Administrative Assistant (Remote) Job.gdoc
# Josephine Duba Kanu_C7_Essay Title: From Majors to Missions: A Journey of Purpose and Impact at ALU.gdoc
# Josephine Duba Kanu_C7_Group3 (1).gdoc
# Josephine Duba Kanu_C7_Group3.gdoc
# Josephine Duba Kanu_Chort7_Group1_Promt 1: Academic Research.gdoc
# Josephine Duba Kanu_Formative Essay.gdoc
# Josephine Duba Kanu_Gravity Research Cover Letter.gdoc
# Josephine Duba Kanu_IFAD_Cover Letter.gdoc
# Josephine Duba Kanu_Internship_Letter .gdoc
# Josephine Duba Kanu_Internship_Letter .pdf
# Josephine Duba Kanu_January 2024_Final Scholars Profile. (1).pdf
# Josephine Duba Kanu_January 2024_Final Scholars Profile..gslides
# Josephine Duba Kanu_January 2024_Final Scholars Profile..pdf
# Josephine Duba Kanu_Learning Process Summative Assessment.gdoc
# Josephine Duba Kanu_Module 1 Reflection.gdoc
# Josephine Duba Kanu_Module 2 Reflection.gdoc
# Josephine Duba Kanu_Module 3 Reflection.gdoc
# Josephine Duba Kanu_My Mission Journal_C7.pptx
# Josephine Duba Kanu_My Personal Mission Statement Workbook.pptx.pdf
# Josephine Duba Kanu_SQL Query.drawio
# Josephine Duba Kanu_Summative_July 31 2025.gdoc
# Josephine Duba Kanu_USAf   HESA Document.gdoc
# Josephine Duba Kanu_Unit Two Assignment.docx
# Josephine Duba Kanu_Weekly_Report_02.docx
# Josephine Duba NEW_20250603_164721_0027.png
# Josephine Term Registration.jpg
# Josephine duba kanu.gdoc
# JosephineDubaKanu_FinalProject.docx
# JosephineDubaKanu_LearningJournal.gslides
# JosephineDubaKanu_LearningJournal.pptx
# JosephineKanu_Unit Four Assignment.docx
# JosephineKanu_Unit Three Assignment.docx
# Josephine_Duba _Kanu Consent Form.gdoc
# Josephine_Duba_Kanu Mission Development Narrative – SafeBirth Sierra Leone.gdoc
# Josephine_Duba_Kanu_CV (1).pdf
# Josephine_Duba_Kanu_CV (2).pdf
# Josephine_Duba_Kanu_CV.pdf
# Josephine_Duba_Kanu_Reflective Thinking_Assignment.gdoc
# Josephine_Duba_SDL Assingment.gdoc
# Josephine_Kanu_MCF_Budget.xlsx
# Josephine_Kanu_MCF_Budget.xlsx.gsheet
# Josephine_Mastercard Foundation Scholars Program.gdoc
# Josephine_Mindora Health — Weekly Report.gdoc
# Karim Fofanah (Official Documentation to Confirm My Humanitarian Status).gdoc
# Karim Fofanah (Official Documentation to Confirm My Humanitarian Status).pdf
# Kenya Ticket.jpg
# Key Steps to Take as an Individual.gdoc
# Kigali - Nirobi Payment Slip.jpg
# LETTER OF RECOMMENDATION FOR JOSEPHINE DUBA KANU (Dr. Fatmata Mansaray).gdoc
# LETTER OF RECOMMENDATION FOR JOSEPHINE DUBA KANU (Dr. Hassan Alieu Swaray).gdoc
# LETTER OF RECOMMENDATION FOR JOSEPHINE DUBA KANU (Dr. Hassan Alieu Swaray).pdf
# Letter of Reference for Karim Fofanah (1).gdoc
# Letter of Reference for Karim Fofanah.gdoc
# Letter of Reference for Karim Fofanah.pdf
# Machine Learning Techniques – I.mp4
# Maternal Health Risk Prediction
# Maternal Health Risk Prediction.gdoc
# Maternal dataset Summative
# Mens_Mental_Health_Content_Package.docx
# Methods of Persuasion_Joephine Duba Kanu.gslides
# Mindora_Communication_Plan_v4.docx
# Mindora_Week5_Content_Plan.docx
# Money_minder Team 5.gslides
# Mr. Pawah Saidu Khanu - Recommendation Letter.gdoc
# My Passport.png
# My Personal Mission Video Story (Josephine Duba Kanu).mp4
# My passport Picture.png
# My token:.gdoc
# Negpod 6_updated submission_Group coding summative.gdoc
# Official JOSEPHINE DEBA KANU Resume_CV (2024) (1).pdf
# Official JOSEPHINE DEBA KANU Resume_CV (2024) (2).pdf
# Official JOSEPHINE DEBA KANU Resume_CV (2024) (3).pdf
# Official JOSEPHINE DEBA KANU Resume_CV (2024).gdoc
# Official JOSEPHINE DEBA KANU Resume_CV (2024).pdf
# Official JOSEPHINE DUBA KANU Resume CV (2025).gdoc
# Official JOSEPHINE DUBA KANU Resume_CV (1).pdf
# Official JOSEPHINE DUBA KANU Resume_CV (2).pdf
# Official JOSEPHINE DUBA KANU Resume_CV (2025) (2) (1).pdf
# Official JOSEPHINE DUBA KANU Resume_CV (2025) (2) (2).pdf
# Official JOSEPHINE DUBA KANU Resume_CV (2025) (2) (3).pdf
# Official JOSEPHINE DUBA KANU Resume_CV (2025) (2) (4).pdf
# Official JOSEPHINE DUBA KANU Resume_CV (2025) (2) (5).pdf
# Official JOSEPHINE DUBA KANU Resume_CV (2025) (2) (6).pdf
# Official JOSEPHINE DUBA KANU Resume_CV (2025) (2) (7).pdf
# Official JOSEPHINE DUBA KANU Resume_CV (2025) (2).pdf
# Official JOSEPHINE DUBA KANU Resume_CV (2025) (3).pdf
# Official JOSEPHINE DUBA KANU Resume_CV (3).pdf
# Official JOSEPHINE DUBA KANU Resume_CV (4).pdf
# Official JOSEPHINE DUBA KANU Resume_CV (5).pdf
# Official JOSEPHINE DUBA KANU Resume_CV (6).pdf
# Official JOSEPHINE DUBA KANU Resume_CV (7).pdf
# Official JOSEPHINE DUBA KANU Resume_CV (8).pdf
# Official JOSEPHINE DUBA KANU Resume_CV.gdoc
# Official JOSEPHINE DUBA KANU Resume_CV.pdf
# Official JOSEPHINE DUBA KANUResume (CV)_removed_removed.docx
# Official JOSEPHINE DUBA KANUResume (CV)_removed_removed.gdoc
# Official JOSEPHINE DUBA KANUResume (CV)_removed_removed.pdf
# Personal Statement for Bachelor of Midwifery Program at Africa Health Sciences University (AHSU).gdoc
# Pesonal Essay For studying Medicine (Josephine Duba Kanu).gdoc
# Pitch deck_Josephine Duba Kanu (1).pdf
# Pitch deck_Josephine Duba Kanu.pdf
# Pregnant women Visit Report at CONNAUGHT Hospital and ADVANTIST Hospital in Freetown.pdf
# Presentation Group Assignment.gslides
# Project Proposal.gdoc
# Project-team_5_first_class_presentation.gslides
# Proof of Certificate
# Prototype Structure.gdoc
# Public Sector Student Innovation Hackathon Submission – [Josephine Duba Kanu   Paul Ernest Theophilus Valcarcel].pptx
# RECOMMENDATION FOR JOSEPHINE DUBA KANU.pdf
# Recommendation LetterJosephine Duba Kanu.gdoc
# Recommendation LetterJosephine Duba Kanu.pdf
# Reference Letter For Mr.gdoc
# Referral Letter for Josephine Duba Kanu – Rise Again Project.gdoc
# Responsible Enterprise_Empathy Map_Josephine Duba Kanu.gdoc
# Rise Again is a grassroots initiative founded in 2025 and is currently not registered as a formal nonprofit organization.gdoc
# Rise Again is a newly formed initiative in its pilot phase.gdoc
# Rise Again – Project Proposal.gdoc
# Rise+Again+-+Empowering+Teenage+Mothers+in+Sierra+Leone.pdf
# Rise_Again_Pitch_Deck - Josephine Kanu.gdoc
# Rise_Again_Pitch_Deck.docx
# Rise_Again_Pitch_Deck.pdf
# S D L
# SAFEBIRTH_PitchDeck_Final.pptx
# SafeBirth Sierra Leone Project
# Saidu Pawah Khanu_Documentation to verify the income details.gdoc
# Scaling Strategy for SafeBirth Sierra Leone _Josephine Duba Kanu.gdoc
# Scaling Strategy for SafeBirth Sierra Leone _Josephine Duba Kanu.pdf
# Screen Recording 2026-06-22 at 1.24.24 AM.mov
# Screenshot_20240321-191101.jpg
# Sierra Safe Birth Action Plan.gdoc
# Task:Calendar_Josephine Kanu.gdoc
# Technology has become the foundation of modern banking.gdoc
# Testimonial.gdoc
# Topic 1: Ethics in technological development: Betterment versus responsibility_Formative Assignment.gdoc
# Two recipt payment (1).pdf
# Two recipt payment.pdf
# UNFPA Global Internship Cover Letter — Josephine Duba Kanu.gdoc
# Unofficial Academic Transcript (3) (1).pdf
# Unofficial Academic Transcript (3) (2).pdf
# Unofficial Academic Transcript (3).pdf
# Untitled Diagram.drawio
# Untitled document (1).gdoc
# Untitled document (10).gdoc
# Untitled document (11).gdoc
# Untitled document (12).gdoc
# Untitled document (13).gdoc
# Untitled document (14).gdoc
# Untitled document (15).gdoc
# Untitled document (16).gdoc
# Untitled document (17).gdoc
# Untitled document (18).gdoc
# Untitled document (19).gdoc
# Untitled document (2).gdoc
# Untitled document (20).gdoc
# Untitled document (21).gdoc
# Untitled document (22).gdoc
# Untitled document (23).gdoc
# Untitled document (24).gdoc
# Untitled document (25).gdoc
# Untitled document (26).gdoc
# Untitled document (27).gdoc
# Untitled document (28).gdoc
# Untitled document (29).gdoc
# Untitled document (3).gdoc
# Untitled document (30).gdoc
# Untitled document (31).gdoc
# Untitled document (32).gdoc
# Untitled document (33).gdoc
# Untitled document (34).gdoc
# Untitled document (35).gdoc
# Untitled document (36).gdoc
# Untitled document (37).gdoc
# Untitled document (38).gdoc
# Untitled document (39).gdoc
# Untitled document (4).gdoc
# Untitled document (40).gdoc
# Untitled document (5).gdoc
# Untitled document (6).gdoc
# Untitled document (7).gdoc
# Untitled document (8).gdoc
# Untitled document (9).gdoc
# Untitled document.gdoc
# Untitled presentation.gslides
# Visa Payment.png
# WAAW FOUNDATION
# WAAW FOUNDATION Outreached at Groupe Scolaire Kimironko 01 High School (KIGALI, RWANDA) .gdoc
# WAAW OUTREACH
# Week4_Content_Plan_v2.docx
# Weekly_Content_Structure_Week3.docx
# Weekly_Report_01 (1).docx
# Weekly_Report_03.docx
# What is SAFEBIRTH.gdoc
# WhatsApp Image 2024-09-08 at 18.18.09_67b1e5b6.jpg
# WhatsApp Image 2024-09-20 at 16.02.00_9385bcd3.jpg
# WhatsApp Image 2025-06-13 at 18.55.30_7f6a87d3.jpg
# WhatsApp Image 2026-01-19 at 20.29.32 (1).jpeg
# WhatsApp Image 2026-01-19 at 20.29.32.jpeg
# Yeanoh Kanu_Documentation to verify the income details.pdf
# ZAMBEZI Catalyst Challenge 5 Submission.pptx
# ZAMBEZI Catalysts Group Presentation Slides.gslides
# Zainab Aminata Fofanah_ Ethics_in_Public_Administration.docx
# Zindi_HealthQA
# Zindua School Interview questions.gdoc
# _Josephine Duba Kanu_Mission Portfolio.docx
# archive
# diabetes_model.pkl
# icon.png
# imgonline-com-ua-resize-FoTDZXqfYluYpn.jpg
# j.kanu@alustudent.com-IndividualProject.gdoc
# j.kanu_FirstFlutterProject.gdoc
# may 2025 registration.jpg
# message.jpg
# payment 2 (1).jpg
# payment 2.jpg
# references.gdoc
# summative work (1) (1).mp4
# visa 1 (1).jpg
# visa 1.jpg
# visa 2 (1).pdf
# visa 2.pdf
# “N A – unregistered community initiative based in Sierra Leone.gdoc
# “Not applicable – we are not a registered U.gdoc

# %%
# Check what's inside your HMM_Project folder
data_path = '/content/drive/MyDrive/HMM_Project'

print("Folders inside HMM_Project:")
for folder in sorted(os.listdir(data_path)):
    print(folder)
# Out:
# Folders inside HMM_Project:
# jumping_01
# jumping_02
# jumping_03
# jumping_04
# jumping_05
# jumping_06
# jumping_07
# jumping_08
# jumping_09
# jumping_0_10
# jumping_0_11
# jumping_0_12
# jumping_0_13
# standing_01
# standing_02
# standing_03
# standing_04
# standing_05
# standing_06
# standing_07
# standing_08
# standing_09
# standing_0_10
# standing_0_11
# standing_0_12
# standing_0_13
# still_01
# still_02
# still_03
# still_04
# still_05
# still_06
# still_07
# still_08
# still_09
# still_0_10
# still_0_11
# still_0_12
# still_0_13
# walking_01.csv
# walking_02
# walking_03
# walking_04
# walking_05
# walking_06
# walking_07
# walking_08
# walking_09
# walking_0_10
# walking_0_11
# walking_0_12
# walking_0_13

# %% [markdown]
# ## Reading Sensor Files
# For each clip, i load the Accelerometer.csv and Gyroscope.csv files and combine
# them into one data array. We load all 52 clips across 4 activities:
# walking, standing, still, and jumping.

# %%
# Load all sensor data from all clips
activities = ['walking', 'standing', 'still', 'jumping']
label_map = {'walking': 0, 'standing': 1, 'still': 2, 'jumping': 3}

def load_clip(clip_path):
    acc_path = os.path.join(clip_path, 'Accelerometer.csv')
    gyr_path = os.path.join(clip_path, 'Gyroscope.csv')
    if not os.path.exists(acc_path) or not os.path.exists(gyr_path):
        return None
    acc = pd.read_csv(acc_path)
    gyr = pd.read_csv(gyr_path)
    acc = acc[['x','y','z']].dropna()
    gyr = gyr[['x','y','z']].dropna()
    min_len = min(len(acc), len(gyr))
    data = np.hstack([acc.values[:min_len], gyr.values[:min_len]])
    return data

all_data = []
all_labels = []
clip_lengths = []

for folder in sorted(os.listdir(data_path)):
    folder_path = os.path.join(data_path, folder)
    if not os.path.isdir(folder_path):
        continue
    for activity in activities:
        if folder.lower().startswith(activity):
            clip = load_clip(folder_path)
            if clip is not None and len(clip) > 10:
                all_data.append(clip)
                all_labels.append(label_map[activity])
                clip_lengths.append(len(clip))
                print(f"Loaded: {folder} ({activity}) — {len(clip)} rows")
            break

print(f"\nTotal clips loaded: {len(all_data)}")
# Out:
# Loaded: jumping_01 (jumping) — 479 rows
# Loaded: jumping_02 (jumping) — 510 rows
# Loaded: jumping_03 (jumping) — 428 rows
# Loaded: jumping_04 (jumping) — 432 rows
# Loaded: jumping_05 (jumping) — 545 rows
# Loaded: jumping_06 (jumping) — 427 rows
# Loaded: jumping_07 (jumping) — 461 rows
# Loaded: jumping_08 (jumping) — 450 rows
# Loaded: jumping_09 (jumping) — 449 rows
# Loaded: jumping_0_10 (jumping) — 484 rows
# Loaded: jumping_0_11 (jumping) — 360 rows
# Loaded: jumping_0_12 (jumping) — 480 rows
# Loaded: jumping_0_13 (jumping) — 438 rows
# Loaded: standing_01 (standing) — 600 rows
# Loaded: standing_02 (standing) — 568 rows
# Loaded: standing_03 (standing) — 582 rows
# Loaded: standing_04 (standing) — 497 rows
# Loaded: standing_05 (standing) — 497 rows
# Loaded: standing_06 (standing) — 495 rows
# Loaded: standing_07 (standing) — 529 rows
# Loaded: standing_08 (standing) — 533 rows
# Loaded: standing_09 (standing) — 1209 rows
# Loaded: standing_0_10 (standing) — 536 rows
# Loaded: standing_0_11 (standing) — 505 rows
# Loaded: standing_0_12 (standing) — 557 rows
# Loaded: standing_0_13 (standing) — 582 rows
# Loaded: still_01 (still) — 519 rows
# Loaded: still_02 (still) — 575 rows
# Loaded: still_03 (still) — 549 rows
# Loaded: still_04 (still) — 520 rows
# Loaded: still_05 (still) — 528 rows
# Loaded: still_06 (still) — 508 rows
# Loaded: still_07 (still) — 484 rows
# Loaded: still_08 (still) — 511 rows
# Loaded: still_09 (still) — 495 rows
# Loaded: still_0_10 (still) — 508 rows
# Loaded: still_0_11 (still) — 503 rows
# Loaded: still_0_12 (still) — 512 rows
# Loaded: still_0_13 (still) — 521 rows
# Loaded: walking_01.csv (walking) — 630 rows
# Loaded: walking_02 (walking) — 413 rows
# Loaded: walking_03 (walking) — 451 rows
# Loaded: walking_04 (walking) — 545 rows
# Loaded: walking_05 (walking) — 503 rows
# Loaded: walking_06 (walking) — 521 rows
# Loaded: walking_07 (walking) — 562 rows
# Loaded: walking_08 (walking) — 459 rows
# Loaded: walking_09 (walking) — 525 rows
# Loaded: walking_0_10 (walking) — 532 rows
# Loaded: walking_0_11 (walking) — 582 rows
# Loaded: walking_0_12 (walking) — 583 rows
# Loaded: walking_0_13 (walking) — 539 rows
#
# Total clips loaded: 52

# %% [markdown]
# ## Feature Extraction
# From each clip i extract 30 features — 5 per sensor axis across 6 axes
# (3 accelerometer + 3 gyroscope).
#
# Time-domain features:
# - Mean: average signal value
# - Variance: how much the signal fluctuates
# - RMS (Root Mean Square): overall signal strength
#
# Frequency-domain features (from FFT):
# - Dominant frequency: the most prominent movement frequency
# - Spectral energy: total energy in the frequency spectrum
#
# All features are normalized using Z-score (StandardScaler) so no single
# feature dominates the model.

# %%
# Extract features from each clip
def extract_features(data):
    features = []
    for axis in range(data.shape[1]):
        signal = data[:, axis]
        # Time-domain features
        features.append(np.mean(signal))
        features.append(np.var(signal))
        features.append(np.sqrt(np.mean(signal**2)))  # RMS
        # Frequency-domain features
        fft_vals = np.abs(fft(signal))
        features.append(np.argmax(fft_vals))  # dominant frequency
        features.append(np.sum(fft_vals**2))  # spectral energy
    return np.array(features)

# Extract features for all clips
X_features = []
for clip in all_data:
    feat = extract_features(clip)
    X_features.append(feat)

X_features = np.array(X_features)

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_features)

print(f"Feature matrix shape: {X_scaled.shape}")
print("Features extracted and normalized!")
# Out:
# Feature matrix shape: (52, 30)
# Features extracted and normalized!

# %% [markdown]
# ## Training the Hidden Markov Model
# I train one GaussianHMM per activity using the Baum-Welch algorithm.
# - 4 hidden states total (one per activity)
# - Convergence threshold: tol=1e-4 (log-likelihood based stopping criterion)
# - 80% of data used for training, 20% reserved for testing

# %%
# Train the Hidden Markov Model
from sklearn.model_selection import train_test_split

# Split data: 80% training, 20% testing
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, all_labels, test_size=0.2, random_state=42, stratify=all_labels
)

# Train one HMM per activity
models = {}
activity_names = ['walking', 'standing', 'still', 'jumping']

for label, activity in enumerate(activity_names):
    # Get training data for this activity only
    X_activity = X_train[np.array(y_train) == label]

    if len(X_activity) < 2:
        print(f"Not enough data for {activity}")
        continue

    model = hmm.GaussianHMM(
        n_components=2,
        covariance_type='diag',
        n_iter=100,
        tol=1e-4
    )
    model.fit(X_activity)
    models[label] = model
    print(f"Trained model for: {activity} ({len(X_activity)} clips)")

print("\nAll models trained!")
# Out:
# WARNING:hmmlearn.base:Model is not converging.  Current: 476.9023341589921 is not greater than 484.3241375448361. Delta is -7.421803385843987
# WARNING:hmmlearn.base:Model is not converging.  Current: 576.2381598491806 is not greater than 593.2992055952291. Delta is -17.06104574604842
# Trained model for: walking (10 clips)
# Trained model for: standing (11 clips)
# Trained model for: still (10 clips)
# Trained model for: jumping (10 clips)
#
# All models trained!

# %% [markdown]
# ## Viterbi Decoding
# I use the Viterbi algorithm to decode the most likely activity for each
# test clip. Each clip is scored against all 4 trained models and assigned
# to the activity with the highest log-likelihood score.

# %%
# Viterbi decoding - predict activity for each test clip
def predict_activity(x, models):
    best_score = float('-inf')
    best_label = -1
    for label, model in models.items():
        try:
            score = model.score(x.reshape(1, -1))
            if score > best_score:
                best_score = score
                best_label = label
        except:
            pass
    return best_label

# Predict on test set
y_pred = []
for x in X_test:
    pred = predict_activity(x, models)
    y_pred.append(pred)

y_pred = np.array(y_pred)
y_test = np.array(y_test)

# Overall accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Overall Accuracy: {accuracy * 100:.2f}%")
print(f"\nTrue labels:      {y_test}")
print(f"Predicted labels: {y_pred}")
print(f"\n0=walking, 1=standing, 2=still, 3=jumping")
# Out:
# Overall Accuracy: 100.00%
#
# True labels:      [2 0 3 1 0 1 2 3 2 3 0]
# Predicted labels: [2 0 3 1 0 1 2 3 2 3 0]
#
# 0=walking, 1=standing, 2=still, 3=jumping

# %% [markdown]
# ## Evaluation — Confusion Matrix
# The confusion matrix shows how many clips were correctly and incorrectly
# classified. A perfect diagonal means every activity was classified correctly.

# %%
# Confusion Matrix
plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=activity_names,
            yticklabels=activity_names)
plt.title('Confusion Matrix')
plt.ylabel('True Activity')
plt.xlabel('Predicted Activity')
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/HMM_Project/confusion_matrix.png', dpi=150)
plt.show()
print("Confusion matrix saved!")
# Out:
# Confusion matrix saved!

# %% [markdown]
# ## Transition Matrices
# The transition matrix for each activity shows the probability of moving
# between hidden states within that activity. High diagonal values mean
# the model tends to stay in the same state reflecting stable,
# repetitive movements.

# %%
# Transition Matrix Heatmap for each activity model
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

for label, activity in enumerate(activity_names):
    if label in models:
        trans_mat = models[label].transmat_
        sns.heatmap(trans_mat, annot=True, fmt='.2f', cmap='YlOrRd',
                    ax=axes[label],
                    xticklabels=[f'State {i+1}' for i in range(trans_mat.shape[0])],
                    yticklabels=[f'State {i+1}' for i in range(trans_mat.shape[0])])
        axes[label].set_title(f'Transition Matrix — {activity}')
        axes[label].set_ylabel('From State')
        axes[label].set_xlabel('To State')

plt.suptitle('HMM Transition Matrices by Activity', fontsize=14)
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/HMM_Project/transition_matrices.png', dpi=150)
plt.show()
print("Transition matrices saved!")
# Out:
# Transition matrices saved!

# %% [markdown]
# ## Emission Probabilities
# The emission probability heatmaps show how strongly each hidden state
# responds to each feature. Different activities show distinct patterns,
# confirming that our features successfully distinguish between activities.

# %%
# Emission Probabilities (Means) Heatmap
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()

feature_labels = []
sensors = ['acc_x', 'acc_y', 'acc_z', 'gyr_x', 'gyr_y', 'gyr_z']
feat_types = ['mean', 'var', 'rms', 'dom_freq', 'spectral_energy']
for s in sensors:
    for f in feat_types:
        feature_labels.append(f'{s}_{f}')

for label, activity in enumerate(activity_names):
    if label in models:
        means = models[label].means_
        sns.heatmap(means, annot=True, fmt='.2f', cmap='coolwarm',
                    ax=axes[label],
                    xticklabels=feature_labels,
                    yticklabels=[f'State {i+1}' for i in range(means.shape[0])])
        axes[label].set_title(f'Emission Means — {activity}')
        axes[label].set_xticklabels(feature_labels, rotation=90, fontsize=7)

plt.suptitle('HMM Emission Probabilities by Activity', fontsize=14)
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/HMM_Project/emission_probabilities.png', dpi=150)
plt.show()
print("Emission probabilities saved!")
# Out:
# Emission probabilities saved!

# %% [markdown]
# ## Performance Metrics
# I compute sensitivity, specificity, and accuracy for each activity:
# - Sensitivity: ability to correctly detect an activity when it occurs
# - Specificity: ability to correctly reject an activity when it is not occurring
# - Accuracy: overall correctness of the model

# %%
# Sensitivity, Specificity, Accuracy per activity
print("=" * 60)
print(f"{'Activity':<12} {'Sensitivity':>12} {'Specificity':>12} {'Accuracy':>10}")
print("=" * 60)

for label, activity in enumerate(activity_names):
    TP = np.sum((y_test == label) & (y_pred == label))
    TN = np.sum((y_test != label) & (y_pred != label))
    FP = np.sum((y_test != label) & (y_pred == label))
    FN = np.sum((y_test == label) & (y_pred != label))

    sensitivity = TP / (TP + FN) if (TP + FN) > 0 else 0
    specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
    accuracy = (TP + TN) / (TP + TN + FP + FN)

    print(f"{activity:<12} {sensitivity*100:>11.1f}% {specificity*100:>11.1f}% {accuracy*100:>9.1f}%")

print("=" * 60)
print(f"\nOverall Accuracy: {accuracy_score(y_test, y_pred)*100:.2f}%")
# Out:
# ============================================================
# Activity      Sensitivity  Specificity   Accuracy
# ============================================================
# walking            100.0%       100.0%     100.0%
# standing           100.0%       100.0%     100.0%
# still              100.0%       100.0%     100.0%
# jumping            100.0%       100.0%     100.0%
# ============================================================
#
# Overall Accuracy: 100.00%

# %% [markdown]
# ## Decoded Sequence Visualization
# This plot shows the true activity labels versus the predicted labels
# from Viterbi decoding across all test clips. Overlapping lines confirm
# perfect classification.

# %%
# Decoded sequence plot
plt.figure(figsize=(12, 4))
plt.plot(y_test, 'bo-', label='True Activity', markersize=8)
plt.plot(y_pred, 'rx--', label='Predicted Activity', markersize=8)
plt.yticks([0, 1, 2, 3], activity_names)
plt.xlabel('Test Clip Index')
plt.ylabel('Activity')
plt.title('True vs Predicted Activity — Viterbi Decoding')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/HMM_Project/decoded_sequence.png', dpi=150)
plt.show()
print("Decoded sequence plot saved!")
print("\nAll code complete! All visualizations saved to Google Drive.")
# Out:
# Decoded sequence plot saved!
#
# All code complete! All visualizations saved to Google Drive.

# %%
# Remount drive to refresh files
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive')

# Test on unseen data again
test_clips = {
    'teste_walking_01': 0,
    'teste_standing_01': 1
}

print("Testing model on unseen data...")
print("=" * 50)

for folder_name, true_label in test_clips.items():
    clip_path = os.path.join(data_path, folder_name)
    clip = load_clip(clip_path)

    if clip is None:
        print(f"Could not load {folder_name}")
        continue

    features = extract_features(clip)
    features_scaled = scaler.transform(features.reshape(1, -1))
    predicted_label = predict_activity(features_scaled[0], models)

    true_activity = activity_names[true_label]
    predicted_activity = activity_names[predicted_label]
    correct = "✅ CORRECT" if true_label == predicted_label else "❌ WRONG"

    print(f"Clip: {folder_name}")
    print(f"True activity:      {true_activity}")
    print(f"Predicted activity: {predicted_activity}")
    print(f"Result: {correct}")
    print("-" * 50)
# Out:
# Mounted at /content/drive
# Testing model on unseen data...
# ==================================================
# Clip: teste_walking_01
# True activity:      walking
# Predicted activity: walking
# Result: ✅ CORRECT
# --------------------------------------------------
# Clip: teste_standing_01
# True activity:      standing
# Predicted activity: standing
# Result: ✅ CORRECT
# --------------------------------------------------
